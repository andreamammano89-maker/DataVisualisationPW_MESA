# %%
import os
import pandas as pd
import geopandas as gpd

# base directory (cartella del notebook)
HERE = os.path.abspath("")
DATA_DIR = os.path.join(HERE, "data")

# --- ROME ---
ROME_DIR = os.path.join(DATA_DIR, "rome")
df_rome = pd.read_csv(os.path.join(ROME_DIR, "listings_Rome.csv"))
geo_rome = gpd.read_file(os.path.join(ROME_DIR, "neighbourhoods_Rome.geojson"))

# --- COPENHAGEN ---
COP_DIR = os.path.join(DATA_DIR, "copenhagen")
df_cop = pd.read_csv(os.path.join(COP_DIR, "listings_Copenhagen.csv"))
geo_cop = gpd.read_file(os.path.join(COP_DIR, "neighbourhoods_Copenhagen.geojson"))

# preview
df_rome.head()
df_cop.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/Desktop/MLPROJ/ML_Project_SEA_815441/.venv/lib/python3.11/site-packages/pandas/__init__.py:11
#      10 try:
# ---> 11     __import__(_dependency)
#      12 except ImportError as _e:  # pragma: no cover
#
# File ~/Desktop/MLPROJ/ML_Project_SEA_815441/.venv/lib/python3.11/site-packages/numpy/__init__.py:457
#     455 del ta
# --> 457 from . import lib, matrixlib as _mat
#     458 from .lib import scimath as emath
#
# File ~/Desktop/MLPROJ/ML_Project_SEA_815441/.venv/lib/python3.11/site-packages/numpy/lib/__init__.py:18
#      16 # Private submodules
#      17 # load module names. See https://github.com/networkx/networkx/issues/5838
# ---> 18 from . import (
#      19     _arraypad_impl,
#      20     _arraysetops_impl,
#      21     _arrayterator_impl,
#      22     _function_base_impl,
#      23     _histograms_impl,
# ...

# %%
HERE = os.path.abspath('')      
DATA_DIR = os.path.join(HERE, "data")
PATH = os.path.join(DATA_DIR, "ai_productivity_dataset_final.csv")
